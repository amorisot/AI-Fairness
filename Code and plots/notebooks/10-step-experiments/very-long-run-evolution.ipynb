# %%
#import stuff, and set seaborn up
from scipy.stats import norm
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
import pandas as pd
import time
from scipy.optimize import minimize
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %% [markdown]
# # All the functions

# %%
#define functions

#create function that finds mean of a function
def mean_pop(a):
    mean = 0
    for i in range(len(a)):
        mean += a[i]*i

    mean = int(mean/sum(a))

    return mean

#create function that finds mean of a population
def weighted_total(a):
    weighted_total=0
    history_number=np.zeros((100,1)) #100 being the number of possible credit scores
    for i in range(100):
        number=sum(a==i) #number being the number of people having credit score i
        weighted_total+=number*i
        history_number[i]=number
    
    weighted_total/=sum(history_number)
    
    return weighted_total

#creates random distributions
def brownian_population(delta=2, dt=1, n=100, x=0):

    history=np.zeros(n)
    
    # Iterate to compute the steps of the Brownian motion.
    for i in range(n):
        x = x + norm.rvs(scale=delta**2*dt)
        history[i] = x
    
    history = history+np.abs(np.min(history))
    
    original_hist = np.copy(history)
    old_mean = mean_pop(original_hist)
    
    history = np.round(999*history/sum(history))
    
    mean = np.round(np.average(history))
    
    if sum(history) < 999:
        history[0] += 999-sum(history)
        
    elif sum(history) > 999:  
        history[np.argmax(history)] -= -999+sum(history)        
    

    return history, old_mean, original_hist

#create function that finds true positive rates as a function of the cutoff
def true_positive_rate(population, population_that_defaulted, cutoff):
    population_bank_thinks_defaulted = population < cutoff
    
    true_positives = np.logical_and(np.logical_not(population_that_defaulted), 
                                    np.logical_not(population_bank_thinks_defaulted))
    
    number_true_positives = sum(true_positives)
    
    false_negatives = np.logical_and(np.logical_not(population_that_defaulted), 
                                     population_bank_thinks_defaulted)
    
    number_false_negatives = sum(false_negatives) 
    
    true_positive_rate = number_true_positives/(number_true_positives+number_false_negatives)
    
    return true_positive_rate

def difference_bw_positive_rates(pop1, pop2, pop1_that_defaulted, 
                                 pop2_that_defaulted, cutoff1, cutoff2, strictness=0.01):
    true_positive_rate_group1 = true_positive_rate(pop1, pop1_that_defaulted, cutoff1)
    true_positive_rate_group2 = true_positive_rate(pop2, pop2_that_defaulted, cutoff2)
    # for the optimiser's constraints
    return strictness - np.abs(true_positive_rate_group1-true_positive_rate_group2)

def difference_bw_selection_rates(pop1, pop2, pop1_that_defaulted, 
                                  pop2_that_defaulted, cutoff1, cutoff2, strictness=0.01):
    
    _, selection_rate_group1, _ = bank_profit(pop1, pop1_that_defaulted, cutoff1)
    _, selection_rate_group2, _ = bank_profit(pop2, pop2_that_defaulted, cutoff2)
    
    return strictness - np.abs(selection_rate_group1-selection_rate_group2)

#create function that finds bank profit as a function of the cutoff
def bank_profit(population, population_that_defaulted, cutoff, 
                revenue_factor=1, cost_factor=3, credit_upside=1, credit_downside=2):
    population_bank_thinks_defaulted = population < cutoff
    
    true_positives = np.logical_and(np.logical_not(population_that_defaulted), 
                                    np.logical_not(population_bank_thinks_defaulted))
    
    paid_back = sum(true_positives)
    false_positives = np.logical_and(population_that_defaulted, 
                                     np.logical_not(population_bank_thinks_defaulted))
    defaulted = sum(false_positives)
    
    profit = paid_back*revenue_factor - defaulted*cost_factor
    selection_rate = sum(np.logical_not(population_bank_thinks_defaulted))/len(population)
    
    credit_change = (paid_back*credit_upside - defaulted*credit_downside)

    
    return profit, selection_rate, credit_change



def total_bank_profit(pop1, pop2, pop1_that_defaulted, pop2_that_defaulted, cutoff1, cutoff2, 
                      revenue_factor=1, cost_factor=2, credit_upside=1, credit_downside=2):
    
    profit_group1, _, _ = bank_profit(pop1, pop1_that_defaulted, cutoff1)
    profit_group2, _, _ = bank_profit(pop2, pop2_that_defaulted, cutoff2)
    
    return -(profit_group1 + profit_group2)

def create_blues_and_oranges():
    a, mean_a, _ = brownian_population()
    b, mean_b, _ = brownian_population()

    if mean_a >= mean_b:
        blues = np.copy(b)
        oranges = np.copy(a)
    elif mean_a < mean_b:
        blues = np.copy(a)
        oranges = np.copy(b)
    else:
        print("um")

    true_blues = np.zeros(1)
    true_oranges = np.zeros(1)
    
    for i in range(100):
        num_blues = int(blues[i])
        num_oranges = int(oranges[i])
        
        if num_blues >= 0 and num_oranges >= 0:

            elements_blues = np.multiply(np.ones(num_blues),i)
            elements_oranges = np.multiply(np.ones(num_oranges), i)

            true_blues = np.concatenate((true_blues, elements_blues), axis=0)
            true_oranges = np.concatenate((true_oranges, elements_oranges), axis=0)

    #determine who defaulted
    blues_who_defaulted = true_blues.T < np.random.uniform(0, 100, (1000,1)).ravel()
    oranges_who_defaulted = true_oranges.T < np.random.uniform(0, 100, (1000,1)).ravel()

    blues = true_blues.T
    oranges = true_oranges.T
    
    return blues, oranges, blues_who_defaulted, oranges_who_defaulted, mean_a, mean_b

# %% [markdown]
# # DO STUFF FOR A VERY LONG TIME

# %%
how_many_iters_ugh = 500
how_much_history = 10

history_initials_blue = np.zeros((how_many_iters_ugh, 1000))
history_initials_orange = np.zeros((how_many_iters_ugh, 1000))

history_final_blue_fair = np.zeros((how_many_iters_ugh, how_much_history, 1000))
history_final_orange_fair = np.zeros((how_many_iters_ugh, how_much_history, 1000))
history_cutoff_fair = np.zeros((how_many_iters_ugh, how_much_history, 2))

history_final_blue_unfair = np.zeros((how_many_iters_ugh, how_much_history, 1000))
history_final_orange_unfair = np.zeros((how_many_iters_ugh, how_much_history, 1000))
history_cutoff_unfair = np.zeros((how_many_iters_ugh, how_much_history, 2))

# %%
for j in range(how_many_iters_ugh):
    
    if(j % 10 ==0):
        print("iteration", j)
    
    t = time.time()
    
    b_neutral, o_neutral, bwd_neutral, owd_neutral, mb, mo = create_blues_and_oranges()
    
    b_unfair = np.copy(b_neutral)
    o_unfair = np.copy(o_neutral)
    bwd_unfair = np.copy(bwd_neutral)
    owd_unfair = np.copy(owd_neutral)

    b_fair = np.copy(b_neutral)
    o_fair = np.copy(o_neutral)
    bwd_fair = np.copy(bwd_neutral)
    owd_fair = np.copy(owd_neutral)
    
    history_initials_blue[j] = b_neutral
    history_initials_orange[j] = o_neutral
    
    for i in range(how_much_history):

        #optimise cutoffs without fairness
        
        to_optimise = lambda x: total_bank_profit(b_unfair, o_unfair, bwd_unfair, 
                                                  owd_unfair, x[0], x[1])

        #initial guess
        cutoffs = np.zeros(2)
        cutoffs[0] = 50
        cutoffs[1] = 50


        #optimise without fairness
        a = (0, 100)
        bounds = (a, a)

        solution_unfair = minimize(to_optimise, cutoffs, 
                            bounds=bounds
                                   , options = {'eps': 3}
                                  )

        x_unfair = solution_unfair.x

        loans_b = b_unfair < x_unfair[0]
        loans_o = o_unfair < x_unfair[1]
        true_positives_b = np.logical_and(np.logical_not(bwd_unfair), np.logical_not(loans_b))
        false_positives_b = np.logical_and(np.logical_not(loans_b), bwd_unfair)

        true_positives_o = np.logical_and(np.logical_not(owd_unfair), np.logical_not(loans_o))
        false_positives_o = np.logical_and(np.logical_not(loans_o), owd_unfair)

        b_unfair[true_positives_b] +=5
        b_unfair[false_positives_b] -=10
        b_unfair[b_unfair<1] = 1
        b_unfair[b_unfair>99] = 99

        o_unfair[true_positives_o] +=5
        o_unfair[false_positives_o] -=10
        o_unfair[o_unfair<1] = 1
        o_unfair[o_unfair>99] = 99

        history_final_blue_unfair[j, i, :]=b_unfair
        history_final_orange_unfair[j, i, :]=o_unfair
        history_cutoff_unfair[i]=x_unfair

        bwd_unfair = b_unfair < np.random.randint(100, size=(1000,))
        owd_unfair = o_unfair < np.random.randint(100, size=(1000,))
    
    for i in range(how_much_history):
        
        #optimise cutoffs WITH fairness
        #what to optimise
        to_optimise = lambda x: total_bank_profit(b_fair, o_fair, bwd_fair, 
                                                  owd_fair, x[0], x[1])

        #what to constrain
        to_constrain = lambda x: difference_bw_positive_rates(b_fair, o_fair, bwd_fair, 
                                                              owd_fair, x[0], x[1])

        #initial guess
        cutoffs = np.zeros(2)
        cutoffs[0] = 50
        cutoffs[1] = 50

        a = (0, 100)
        bounds = (a, a)

        #name constraints
        equal_true_positives = {'type': 'ineq', 'fun': to_constrain}
        cons = ([equal_true_positives])



        solution_fair = minimize(to_optimise, cutoffs, 
                            bounds=bounds, constraints=cons
                                   , options = {'eps': 3, 'maxiter':10}
                                  )

        x_fair = solution_fair.x


        loans_b = b_fair < x_fair[0]
        true_positives_b = np.logical_and(np.logical_not(loans_b), np.logical_not(bwd_fair))
        false_positives_b = np.logical_and(np.logical_not(loans_b), bwd_fair)


        loans_o = o_fair < x_fair[1]
        true_positives_o = np.logical_and(np.logical_not(loans_o), np.logical_not(owd_fair))
        false_positives_o = np.logical_and(np.logical_not(loans_o), owd_fair)

        b_fair[true_positives_b] +=5
        b_fair[false_positives_b] -=10
        b_fair[b_fair<1] = 1
        b_fair[b_fair>99] = 99

        o_fair[true_positives_o] +=5
        o_fair[false_positives_o] -=10
        o_fair[o_fair<1] = 1
        o_fair[o_fair>99] = 99

#         b_fair-=0.5
#         o_fair-=0.5

        history_final_blue_fair[j,i,:]=b_fair
        history_final_orange_fair[j,i,:]=o_fair
        history_cutoff_fair[j,i,:]=x_fair
        

        bwd_fair = b_fair < np.random.randint(100, size=(1000,))
        owd_fair = o_fair < np.random.randint(100, size=(1000,))
    
    if (j % 50 == 0):
        print("50 iterations took", (time.time() - t)/60, "minutes")
# Out:
# iteration 0
# 50 iterations took 0.6292333205540975 minutes
# iteration 10
# iteration 20
# iteration 30
# /anaconda/envs/mlp/lib/python3.6/site-packages/ipykernel_launcher.py:90: RuntimeWarning: invalid value encountered in less
# /anaconda/envs/mlp/lib/python3.6/site-packages/ipykernel_launcher.py:56: RuntimeWarning: invalid value encountered in less
# /anaconda/envs/mlp/lib/python3.6/site-packages/ipykernel_launcher.py:105: RuntimeWarning: invalid value encountered in less
# /anaconda/envs/mlp/lib/python3.6/site-packages/ipykernel_launcher.py:110: RuntimeWarning: invalid value encountered in less
# iteration 40
# iteration 50
# 50 iterations took 0.6030548493067424 minutes
# iteration 60
# iteration 70
# iteration 80
# iteration 90
# iteration 100
# 50 iterations took 0.5410187363624572 minutes
# iteration 110
# iteration 120
# iteration 130
# iteration 140
# iteration 150
# 50 iterations took 0.6242139975229899 minutes
# iteration 160
# iteration 170
# iteration 180
# iteration 190
# iteration 200
# 50 iterations took 0.7110395510991414 minutes
# iteration 210
# iteration 220
# iteration 230
# iteration 240
# iteration 250
# 50 iterations took 0.6332014679908753 minutes
# iteration 260
# iteration 270
# iteration 280
# iteration 290
# iteration 300
# 50 iterations took 0.7779568831125895 minutes
# iteration 310
# iteration 320
# iteration 330
# iteration 340
# iteration 350
# 50 iterations took 0.7085332155227662 minutes
# iteration 360
# iteration 370
# iteration 380
# iteration 390
# iteration 400
# 50 iterations took 0.5789123018582661 minutes
# iteration 410
# iteration 420
# iteration 430
# iteration 440
# iteration 450
# 50 iterations took 0.690673021475474 minutes
# iteration 460
# iteration 470
# iteration 480
# iteration 490

# %% [markdown]
# Infrastructure to analyse stuff

# %%
# history_initials_blue
# history_initials_orange

# history_final_blue_fair
# history_final_orange_fair
# history_cutoff_fair

# history_final_blue_unfair
# history_final_orange_unfair
# history_cutoff_unfair

# %%
weighted_total(history_final_blue_fair[0,2,:])
# Out:
# array([35.408])

# %%
fairs_blue = np.zeros((how_many_iters_ugh, how_much_history))
unfairs_blue = np.zeros((how_many_iters_ugh, how_much_history))
fairs_orange = np.zeros((how_many_iters_ugh, how_much_history))
unfairs_orange = np.zeros((how_many_iters_ugh, how_much_history))

# %%
for j in range(how_many_iters_ugh):    
    
    print("iteration", j)
    
    t = time.time()
    
    for i in range(how_much_history):
        
        fairs_blue[j,i] = weighted_total(history_final_blue_fair[j,i,:])
        unfairs_blue[j,i] =  weighted_total(history_final_blue_unfair[j,i,:])
        fairs_orange[j,i] = weighted_total(history_final_orange_fair[j,i,:])
        unfairs_orange[j,i] =  weighted_total(history_final_orange_unfair[j,i,:])
        
    print("one iteration took", time.time() - t, "seconds")
# Out:
# iteration 0
# one iteration took 10.543122053146362 seconds
# iteration 1
# one iteration took 10.848273992538452 seconds
# iteration 2
# one iteration took 10.629408121109009 seconds
# iteration 3
# one iteration took 10.347086906433105 seconds
# iteration 4
# one iteration took 10.53053331375122 seconds
# iteration 5
# one iteration took 11.055007934570312 seconds
# iteration 6
# one iteration took 14.602033853530884 seconds
# iteration 7
# one iteration took 13.5629141330719 seconds
# iteration 8
# one iteration took 11.295936107635498 seconds
# iteration 9
# one iteration took 10.493208885192871 seconds
# iteration 10
# one iteration took 11.887367248535156 seconds
# iteration 11
# one iteration took 10.955497980117798 seconds
# iteration 12
# one iteration took 10.374873161315918 seconds
# iteration 13
# one iteration took 10.337922096252441 seconds
# iteration 14
# one iteration took 11.75898003578186 seconds
# iteration 15
# one iteration took 12.416213989257812 seconds
# iteration 16
# one iteration took 10.651891946792603 seconds
# iteration 17
# one iteration took 10.660609006881714 seconds
# iteration 18
# one iteration took 10.638402223587036 seconds
# iteration 19
# one iteration took 10.807927131652832 seconds
# iteration 20
# one iteration took 10.722474098205566 seconds
# iteration 21
# one iteration took 10.731613874435425 seconds
# iteration 22
# one iteration took 11.506988763809204 seconds
# iteration 23
# one iteration took 11.956587076187134 seconds
# iteration 24
# one iteration took 13.681313037872314 seconds
# iteration 25
# one iteration took 13.047443151473999 seconds
# iteration 26
# one iteration took 10.523866891860962 seconds
# iteration 27
# one iteration took 11.778779029846191 seconds
# iteration 28
# one iteration took 10.957190036773682 seconds
# iteration 29
# one iteration took 10.682233810424805 seconds
# iteration 30
# one iteration took 10.937523126602173 seconds
# iteration 31
# one iteration took 10.950083017349243 seconds
# iteration 32
# one iteration took 10.565667867660522 seconds
# iteration 33
# one iteration took 10.637448072433472 seconds
# iteration 34
# one iteration took 13.218566179275513 seconds
# iteration 35
# one iteration took 12.288413047790527 seconds
# iteration 36
# one iteration took 11.002731084823608 seconds
# iteration 37
# one iteration took 11.020610094070435 seconds
# iteration 38
# one iteration took 10.98067307472229 seconds
# iteration 39
# one iteration took 11.18162989616394 seconds
# iteration 40
# one iteration took 10.311139822006226 seconds
# iteration 41
# one iteration took 10.30314588546753 seconds
# iteration 42
# one iteration took 10.58930492401123 seconds
# iteration 43
# one iteration took 10.671600818634033 seconds
# iteration 44
# one iteration took 10.318464040756226 seconds
# iteration 45
# one iteration took 10.479015111923218 seconds
# iteration 46
# one iteration took 10.473158836364746 seconds
# iteration 47
# one iteration took 10.679232835769653 seconds
# iteration 48
# one iteration took 11.447870016098022 seconds
# iteration 49
# one iteration took 10.89792513847351 seconds
# iteration 50
# one iteration took 10.30036973953247 seconds
# iteration 51
# one iteration took 10.248162031173706 seconds
# iteration 52
# one iteration took 12.115494728088379 seconds
# iteration 53
# one iteration took 14.80536413192749 seconds
# iteration 54
# one iteration took 11.92051887512207 seconds
# iteration 55
# one iteration took 10.91607117652893 seconds
# iteration 56
# one iteration took 11.46848177909851 seconds
# iteration 57
# one iteration took 10.895753145217896 seconds
# iteration 58
# one iteration took 11.112662076950073 seconds
# iteration 59
# one iteration took 10.7255859375 seconds
# iteration 60
# one iteration took 10.979214906692505 seconds
# iteration 61
# one iteration took 10.658524990081787 seconds
# iteration 62
# one iteration took 10.60797119140625 seconds
# iteration 63
# one iteration took 10.358652114868164 seconds
# iteration 64
# one iteration took 10.163938999176025 seconds
# iteration 65
# one iteration took 10.231205701828003 seconds
# iteration 66
# one iteration took 10.220382928848267 seconds
# iteration 67
# one iteration took 10.300433158874512 seconds
# iteration 68
# one iteration took 10.553184986114502 seconds
# iteration 69
# one iteration took 12.696704864501953 seconds
# iteration 70
# one iteration took 10.545856952667236 seconds
# iteration 71
# one iteration took 11.610599994659424 seconds
# iteration 72
# one iteration took 11.122942209243774 seconds
# iteration 73
# one iteration took 10.749696969985962 seconds
# iteration 74
# one iteration took 10.660695791244507 seconds
# iteration 75
# one iteration took 10.796036005020142 seconds
# iteration 76
# one iteration took 10.853754043579102 seconds
# iteration 77
# one iteration took 12.32795786857605 seconds
# iteration 78
# one iteration took 12.334640979766846 seconds
# iteration 79
# one iteration took 12.073668003082275 seconds
# iteration 80
# one iteration took 10.629698991775513 seconds
# iteration 81
# one iteration took 11.233116149902344 seconds
# iteration 82
# one iteration took 10.525099992752075 seconds
# iteration 83
# one iteration took 10.170994281768799 seconds
# iteration 84
# one iteration took 10.037121057510376 seconds
# iteration 85
# one iteration took 10.065940856933594 seconds
# iteration 86
# one iteration took 10.18686819076538 seconds
# iteration 87
# one iteration took 10.16957688331604 seconds
# iteration 88
# one iteration took 10.087457180023193 seconds
# iteration 89
# one iteration took 10.17130422592163 seconds
# iteration 90
# one iteration took 10.180166006088257 seconds
# iteration 91
# one iteration took 10.177916049957275 seconds
# iteration 92
# one iteration took 10.13078498840332 seconds
# iteration 93
# one iteration took 10.165540218353271 seconds
# iteration 94
# one iteration took 10.599583864212036 seconds
# iteration 95
# one iteration took 10.124752283096313 seconds
# iteration 96
# one iteration took 10.15743899345398 seconds
# iteration 97
# one iteration took 10.081463098526001 seconds
# iteration 98
# one iteration took 10.04446005821228 seconds
# iteration 99
# one iteration took 10.16131591796875 seconds
# iteration 100
# one iteration took 10.165319919586182 seconds
# iteration 101
# one iteration took 10.122286081314087 seconds
# iteration 102
# one iteration took 11.306020975112915 seconds
# iteration 103
# one iteration took 11.808049201965332 seconds
# iteration 104
# one iteration took 11.248970985412598 seconds
# iteration 105
# one iteration took 10.72747802734375 seconds
# iteration 106
# one iteration took 11.617146730422974 seconds
# iteration 107
# one iteration took 12.010691165924072 seconds
# iteration 108
# one iteration took 10.656550884246826 seconds
# iteration 109
# one iteration took 10.276041984558105 seconds
# iteration 110
# one iteration took 10.293622970581055 seconds
# iteration 111
# one iteration took 10.231407880783081 seconds
# iteration 112
# one iteration took 10.293102025985718 seconds
# iteration 113
# one iteration took 10.353648900985718 seconds
# iteration 114
# one iteration took 10.129701137542725 seconds
# iteration 115
# one iteration took 10.14877700805664 seconds
# iteration 116
# one iteration took 10.161015033721924 seconds
# iteration 117
# one iteration took 10.220530033111572 seconds
# iteration 118
# one iteration took 15.510854244232178 seconds
# iteration 119
# one iteration took 13.145379066467285 seconds
# iteration 120
# one iteration took 11.525840997695923 seconds
# iteration 121
# one iteration took 11.14439082145691 seconds
# iteration 122
# one iteration took 11.131759881973267 seconds
# iteration 123
# one iteration took 10.199542999267578 seconds
# iteration 124
# one iteration took 10.185386180877686 seconds
# iteration 125
# one iteration took 10.14493703842163 seconds
# iteration 126
# one iteration took 10.260381937026978 seconds
# iteration 127
# one iteration took 10.709043979644775 seconds
# iteration 128
# one iteration took 11.807594060897827 seconds
# iteration 129
# one iteration took 11.63064193725586 seconds
# iteration 130
# one iteration took 10.504817008972168 seconds
# iteration 131
# one iteration took 10.813279867172241 seconds
# iteration 132
# one iteration took 11.394071817398071 seconds
# iteration 133
# one iteration took 10.97347617149353 seconds
# iteration 134
# one iteration took 11.299890995025635 seconds
# iteration 135
# one iteration took 10.862413883209229 seconds
# iteration 136
# one iteration took 10.603884935379028 seconds
# iteration 137
# one iteration took 10.883806943893433 seconds
# iteration 138
# one iteration took 10.228540182113647 seconds
# iteration 139
# one iteration took 11.242828130722046 seconds
# iteration 140
# one iteration took 10.938946008682251 seconds
# iteration 141
# one iteration took 11.671512126922607 seconds
# iteration 142
# one iteration took 10.875598907470703 seconds
# iteration 143
# one iteration took 11.958479881286621 seconds
# iteration 144
# one iteration took 10.194975137710571 seconds
# iteration 145
# one iteration took 11.089995861053467 seconds
# iteration 146
# one iteration took 11.212541103363037 seconds
# iteration 147
# one iteration took 11.304979801177979 seconds
# iteration 148
# one iteration took 11.412081003189087 seconds
# iteration 149
# one iteration took 11.16138219833374 seconds
# iteration 150
# one iteration took 10.91759991645813 seconds
# iteration 151
# one iteration took 11.04426383972168 seconds
# iteration 152
# one iteration took 10.992576122283936 seconds
# iteration 153
# one iteration took 13.717457056045532 seconds
# iteration 154
# one iteration took 14.238092184066772 seconds
# iteration 155
# one iteration took 10.694033861160278 seconds
# iteration 156
# one iteration took 10.61770510673523 seconds
# iteration 157
# one iteration took 10.427638053894043 seconds
# iteration 158
# one iteration took 10.345117092132568 seconds
# iteration 159
# one iteration took 10.238391876220703 seconds
# iteration 160
# one iteration took 10.362552881240845 seconds
# iteration 161
# one iteration took 11.250351190567017 seconds
# iteration 162
# one iteration took 11.129187107086182 seconds
# iteration 163
# one iteration took 10.630756855010986 seconds
# iteration 164
# one iteration took 12.279029846191406 seconds
# iteration 165
# one iteration took 10.219001054763794 seconds
# iteration 166
# one iteration took 10.97116994857788 seconds
# iteration 167
# one iteration took 10.826517105102539 seconds
# iteration 168
# one iteration took 11.749817132949829 seconds
# iteration 169
# one iteration took 12.423896789550781 seconds
# iteration 170
# one iteration took 11.356441974639893 seconds
# iteration 171
# one iteration took 10.7779061794281 seconds
# iteration 172
# one iteration took 11.778637886047363 seconds
# iteration 173
# one iteration took 12.253706216812134 seconds
# iteration 174
# one iteration took 10.349894762039185 seconds
# iteration 175
# one iteration took 10.282547950744629 seconds
# iteration 176
# one iteration took 10.16975998878479 seconds
# iteration 177
# one iteration took 10.325101852416992 seconds
# iteration 178
# one iteration took 10.217673063278198 seconds
# iteration 179
# one iteration took 10.091863870620728 seconds
# iteration 180
# one iteration took 10.384165287017822 seconds
# iteration 181
# one iteration took 10.514328241348267 seconds
# iteration 182
# one iteration took 11.312045097351074 seconds
# iteration 183
# one iteration took 11.2841157913208 seconds
# iteration 184
# one iteration took 10.548694133758545 seconds
# iteration 185
# one iteration took 10.755913019180298 seconds
# iteration 186
# one iteration took 10.706409931182861 seconds
# iteration 187
# one iteration took 10.623147010803223 seconds
# iteration 188
# one iteration took 10.800184965133667 seconds
# iteration 189
# one iteration took 10.683282852172852 seconds
# iteration 190
# one iteration took 11.406147956848145 seconds
# iteration 191
# one iteration took 10.54849624633789 seconds
# iteration 192
# one iteration took 10.784578084945679 seconds
# iteration 193
# one iteration took 11.008246183395386 seconds
# iteration 194
# one iteration took 10.776867151260376 seconds
# iteration 195
# one iteration took 10.25699496269226 seconds
# iteration 196
# one iteration took 10.273396968841553 seconds
# iteration 197
# one iteration took 10.304399728775024 seconds
# iteration 198
# one iteration took 10.39659595489502 seconds
# iteration 199
# one iteration took 10.950690031051636 seconds
# iteration 200
# one iteration took 11.125553131103516 seconds
# iteration 201
# one iteration took 10.406849145889282 seconds
# iteration 202
# one iteration took 10.142123937606812 seconds
# iteration 203
# one iteration took 10.156709909439087 seconds
# iteration 204
# one iteration took 10.177828073501587 seconds
# iteration 205
# one iteration took 10.267644166946411 seconds
# iteration 206
# one iteration took 10.237181186676025 seconds
# iteration 207
# one iteration took 10.175086736679077 seconds
# iteration 208
# one iteration took 10.613537073135376 seconds
# iteration 209
# one iteration took 10.27931022644043 seconds
# iteration 210
# one iteration took 10.168585062026978 seconds
# iteration 211
# one iteration took 10.8699631690979 seconds
# iteration 212
# one iteration took 10.546371936798096 seconds
# iteration 213
# one iteration took 10.428482055664062 seconds
# iteration 214
# one iteration took 10.089498281478882 seconds
# iteration 215
# one iteration took 10.145334005355835 seconds
# iteration 216
# one iteration took 10.071007013320923 seconds
# iteration 217
# one iteration took 10.117218971252441 seconds
# iteration 218
# one iteration took 10.091695070266724 seconds
# iteration 219
# one iteration took 10.180765867233276 seconds
# iteration 220
# one iteration took 10.126722812652588 seconds
# iteration 221
# one iteration took 10.07433795928955 seconds
# iteration 222
# one iteration took 10.260171890258789 seconds
# iteration 223
# one iteration took 10.459688901901245 seconds
# iteration 224
# one iteration took 10.437258958816528 seconds
# iteration 225
# one iteration took 10.201637983322144 seconds
# iteration 226
# one iteration took 10.10691213607788 seconds
# iteration 227
# one iteration took 10.13704776763916 seconds
# iteration 228
# one iteration took 11.648821115493774 seconds
# iteration 229
# one iteration took 10.446429967880249 seconds
# iteration 230
# one iteration took 10.541100025177002 seconds
# iteration 231
# one iteration took 10.948860883712769 seconds
# iteration 232
# one iteration took 11.075577020645142 seconds
# iteration 233
# one iteration took 10.767993927001953 seconds
# iteration 234
# one iteration took 13.24235200881958 seconds
# iteration 235
# one iteration took 10.997757911682129 seconds
# iteration 236
# one iteration took 10.367539167404175 seconds
# iteration 237
# one iteration took 10.228322982788086 seconds
# iteration 238
# one iteration took 10.300004243850708 seconds
# iteration 239
# one iteration took 10.266832113265991 seconds
# iteration 240
# one iteration took 10.100414991378784 seconds
# iteration 241
# one iteration took 10.172128915786743 seconds
# iteration 242
# one iteration took 11.083235025405884 seconds
# iteration 243
# one iteration took 11.14469313621521 seconds
# iteration 244
# one iteration took 10.938609838485718 seconds
# iteration 245
# one iteration took 10.891964197158813 seconds
# iteration 246
# one iteration took 10.827170133590698 seconds
# iteration 247
# one iteration took 10.32280969619751 seconds
# iteration 248
# one iteration took 10.46492600440979 seconds
# iteration 249
# one iteration took 10.782696962356567 seconds
# iteration 250
# one iteration took 11.614353895187378 seconds
# iteration 251
# one iteration took 10.46224594116211 seconds
# iteration 252
# one iteration took 10.55634617805481 seconds
# iteration 253
# one iteration took 10.136220216751099 seconds
# iteration 254
# one iteration took 10.311534881591797 seconds
# iteration 255
# one iteration took 10.414647102355957 seconds
# iteration 256
# one iteration took 10.311882972717285 seconds
# iteration 257
# one iteration took 10.332421064376831 seconds
# iteration 258
# one iteration took 10.286637783050537 seconds
# iteration 259
# one iteration took 10.481680870056152 seconds
# iteration 260
# one iteration took 10.30452585220337 seconds
# iteration 261
# one iteration took 10.210773944854736 seconds
# iteration 262
# one iteration took 10.22856616973877 seconds
# iteration 263
# one iteration took 10.260208129882812 seconds
# iteration 264
# one iteration took 10.123805046081543 seconds
# iteration 265
# one iteration took 10.121135950088501 seconds
# iteration 266
# one iteration took 10.11684513092041 seconds
# iteration 267
# one iteration took 10.243671178817749 seconds
# iteration 268
# one iteration took 10.576664924621582 seconds
# iteration 269
# one iteration took 10.600114822387695 seconds
# iteration 270
# one iteration took 10.356024980545044 seconds
# iteration 271
# one iteration took 10.657027006149292 seconds
# iteration 272
# one iteration took 10.198470115661621 seconds
# iteration 273
# one iteration took 10.45443320274353 seconds
# iteration 274
# one iteration took 11.099838256835938 seconds
# iteration 275
# one iteration took 11.327760934829712 seconds
# iteration 276
# one iteration took 10.984577894210815 seconds
# iteration 277
# one iteration took 10.19986367225647 seconds
# iteration 278
# one iteration took 10.175940752029419 seconds
# iteration 279
# one iteration took 10.127767086029053 seconds
# iteration 280
# one iteration took 13.261329889297485 seconds
# iteration 281
# one iteration took 11.992449045181274 seconds
# iteration 282
# one iteration took 11.308000087738037 seconds
# iteration 283
# one iteration took 13.395562171936035 seconds
# iteration 284
# one iteration took 13.155117988586426 seconds
# iteration 285
# one iteration took 11.236786127090454 seconds
# iteration 286
# one iteration took 12.16395902633667 seconds
# iteration 287
# one iteration took 11.00983190536499 seconds
# iteration 288
# one iteration took 10.122794151306152 seconds
# iteration 289
# one iteration took 10.396269083023071 seconds
# iteration 290
# one iteration took 10.12169075012207 seconds
# iteration 291
# one iteration took 10.370482921600342 seconds
# iteration 292
# one iteration took 10.263744115829468 seconds
# iteration 293
# one iteration took 10.148781061172485 seconds
# iteration 294
# one iteration took 10.437530755996704 seconds
# iteration 295
# one iteration took 10.25423288345337 seconds
# iteration 296
# one iteration took 12.100741147994995 seconds
# iteration 297
# one iteration took 10.585099935531616 seconds
# iteration 298
# one iteration took 10.369935989379883 seconds
# iteration 299
# one iteration took 10.22137713432312 seconds
# iteration 300
# one iteration took 10.096027135848999 seconds
# iteration 301
# one iteration took 10.179821252822876 seconds
# iteration 302
# one iteration took 10.228249073028564 seconds
# iteration 303
# one iteration took 10.949552059173584 seconds
# iteration 304
# one iteration took 10.319254636764526 seconds
# iteration 305
# one iteration took 10.281747102737427 seconds
# iteration 306
# one iteration took 10.191946983337402 seconds
# iteration 307
# one iteration took 10.323163986206055 seconds
# iteration 308
# one iteration took 10.307460069656372 seconds
# iteration 309
# one iteration took 10.286415100097656 seconds
# iteration 310
# one iteration took 10.296793222427368 seconds
# iteration 311
# one iteration took 10.23108720779419 seconds
# iteration 312
# one iteration took 10.321470260620117 seconds
# iteration 313
# one iteration took 10.30818510055542 seconds
# iteration 314
# one iteration took 10.318847894668579 seconds
# iteration 315
# one iteration took 10.322884798049927 seconds
# iteration 316
# one iteration took 10.293133020401001 seconds
# iteration 317
# one iteration took 10.28526496887207 seconds
# iteration 318
# one iteration took 10.866533994674683 seconds
# iteration 319
# one iteration took 10.403662204742432 seconds
# iteration 320
# one iteration took 10.147918939590454 seconds
# iteration 321
# one iteration took 10.261616945266724 seconds
# iteration 322
# one iteration took 10.29315996170044 seconds
# iteration 323
# one iteration took 10.548816919326782 seconds
# iteration 324
# one iteration took 12.047702074050903 seconds
# iteration 325
# one iteration took 11.268536806106567 seconds
# iteration 326
# one iteration took 10.71470308303833 seconds
# iteration 327
# one iteration took 11.459043741226196 seconds
# iteration 328
# one iteration took 10.904103994369507 seconds
# iteration 329
# one iteration took 10.91060185432434 seconds
# iteration 330
# one iteration took 10.310205936431885 seconds
# iteration 331
# one iteration took 10.520513772964478 seconds
# iteration 332
# one iteration took 10.88729190826416 seconds
# iteration 333
# one iteration took 10.429781913757324 seconds
# iteration 334
# one iteration took 10.30285120010376 seconds
# iteration 335
# one iteration took 10.267454147338867 seconds
# iteration 336
# one iteration took 10.23891305923462 seconds
# iteration 337
# one iteration took 10.317609071731567 seconds
# iteration 338
# one iteration took 10.367839097976685 seconds
# iteration 339
# one iteration took 10.42427396774292 seconds
# iteration 340
# one iteration took 11.007803201675415 seconds
# iteration 341
# one iteration took 10.385708093643188 seconds
# iteration 342
# one iteration took 10.299610137939453 seconds
# iteration 343
# one iteration took 10.360237121582031 seconds
# iteration 344
# one iteration took 10.205812931060791 seconds
# iteration 345
# one iteration took 10.741148948669434 seconds
# iteration 346
# one iteration took 11.422491073608398 seconds
# iteration 347
# one iteration took 10.483165264129639 seconds
# iteration 348
# one iteration took 10.913046836853027 seconds
# iteration 349
# one iteration took 10.756161212921143 seconds
# iteration 350
# one iteration took 10.373336791992188 seconds
# iteration 351
# one iteration took 10.413072109222412 seconds
# iteration 352
# one iteration took 10.379278182983398 seconds
# iteration 353
# one iteration took 10.318614721298218 seconds
# iteration 354
# one iteration took 10.302090883255005 seconds
# iteration 355
# one iteration took 10.48653268814087 seconds
# iteration 356
# one iteration took 10.381413221359253 seconds
# iteration 357
# one iteration took 10.805262804031372 seconds
# iteration 358
# one iteration took 10.591140747070312 seconds
# iteration 359
# one iteration took 10.46843695640564 seconds
# iteration 360
# one iteration took 11.172923803329468 seconds
# iteration 361
# one iteration took 10.803419828414917 seconds
# iteration 362
# one iteration took 10.50334882736206 seconds
# iteration 363
# one iteration took 10.205904960632324 seconds
# iteration 364
# one iteration took 10.22873306274414 seconds
# iteration 365
# one iteration took 10.140748977661133 seconds
# iteration 366
# one iteration took 10.239183902740479 seconds
# iteration 367
# one iteration took 10.228446960449219 seconds
# iteration 368
# one iteration took 10.497570037841797 seconds
# iteration 369
# one iteration took 11.324461221694946 seconds
# iteration 370
# one iteration took 10.613635063171387 seconds
# iteration 371
# one iteration took 10.466613054275513 seconds
# iteration 372
# one iteration took 10.515884160995483 seconds
# iteration 373
# one iteration took 10.387715816497803 seconds
# iteration 374
# one iteration took 10.088305950164795 seconds
# iteration 375
# one iteration took 10.215903997421265 seconds
# iteration 376
# one iteration took 11.407999992370605 seconds
# iteration 377
# one iteration took 10.714797019958496 seconds
# iteration 378
# one iteration took 10.206782817840576 seconds
# iteration 379
# one iteration took 10.288573026657104 seconds
# iteration 380
# one iteration took 10.394613027572632 seconds
# iteration 381
# one iteration took 10.238865852355957 seconds
# iteration 382
# one iteration took 10.286699056625366 seconds
# iteration 383
# one iteration took 10.327701807022095 seconds
# iteration 384
# one iteration took 10.64033818244934 seconds
# iteration 385
# one iteration took 10.415796041488647 seconds
# iteration 386
# one iteration took 10.656085968017578 seconds
# iteration 387
# one iteration took 10.33617377281189 seconds
# iteration 388
# one iteration took 10.219653129577637 seconds
# iteration 389
# one iteration took 10.184460163116455 seconds
# iteration 390
# one iteration took 10.219704866409302 seconds
# iteration 391
# one iteration took 10.24951720237732 seconds
# iteration 392
# one iteration took 10.204885005950928 seconds
# iteration 393
# one iteration took 10.147892951965332 seconds
# iteration 394
# one iteration took 10.391724109649658 seconds
# iteration 395
# one iteration took 11.431402921676636 seconds
# iteration 396
# one iteration took 10.238816022872925 seconds
# iteration 397
# one iteration took 10.231401920318604 seconds
# iteration 398
# one iteration took 11.022051095962524 seconds
# iteration 399
# one iteration took 10.236865997314453 seconds
# iteration 400
# one iteration took 10.193888902664185 seconds
# iteration 401
# one iteration took 11.764110803604126 seconds
# iteration 402
# one iteration took 11.086946725845337 seconds
# iteration 403
# one iteration took 10.51698923110962 seconds
# iteration 404
# one iteration took 10.35642695426941 seconds
# iteration 405
# one iteration took 10.606245040893555 seconds
# iteration 406
# one iteration took 10.15135383605957 seconds
# iteration 407
# one iteration took 10.34531307220459 seconds
# iteration 408
# one iteration took 10.19813871383667 seconds
# iteration 409
# one iteration took 10.550173044204712 seconds
# iteration 410
# one iteration took 11.49413514137268 seconds
# iteration 411
# one iteration took 11.348985195159912 seconds
# iteration 412
# one iteration took 11.165135145187378 seconds
# iteration 413
# one iteration took 10.27523398399353 seconds
# iteration 414
# one iteration took 10.55184006690979 seconds
# iteration 415
# one iteration took 10.316855192184448 seconds
# iteration 416
# one iteration took 10.739083051681519 seconds
# iteration 417
# one iteration took 10.518404960632324 seconds
# iteration 418
# one iteration took 10.239006996154785 seconds
# iteration 419
# one iteration took 10.788473129272461 seconds
# iteration 420
# one iteration took 10.324211835861206 seconds
# iteration 421
# one iteration took 10.367899894714355 seconds
# iteration 422
# one iteration took 10.244619131088257 seconds
# iteration 423
# one iteration took 10.714043140411377 seconds
# iteration 424
# one iteration took 10.770328760147095 seconds
# iteration 425
# one iteration took 10.99133014678955 seconds
# iteration 426
# one iteration took 10.16552209854126 seconds
# iteration 427
# one iteration took 10.257382154464722 seconds
# iteration 428
# one iteration took 10.272917032241821 seconds
# iteration 429
# one iteration took 10.258415937423706 seconds
# iteration 430
# one iteration took 10.264564990997314 seconds
# iteration 431
# one iteration took 11.636495113372803 seconds
# iteration 432
# one iteration took 10.404458045959473 seconds
# iteration 433
# one iteration took 10.960267066955566 seconds
# iteration 434
# one iteration took 10.103275060653687 seconds
# iteration 435
# one iteration took 10.267739295959473 seconds
# iteration 436
# one iteration took 10.245306253433228 seconds
# iteration 437
# one iteration took 10.192144870758057 seconds
# iteration 438
# one iteration took 10.256555080413818 seconds
# iteration 439
# one iteration took 10.260938882827759 seconds
# iteration 440
# one iteration took 10.345500230789185 seconds
# iteration 441
# one iteration took 10.248463153839111 seconds
# iteration 442
# one iteration took 10.206235885620117 seconds
# iteration 443
# one iteration took 10.209322929382324 seconds
# iteration 444
# one iteration took 10.856036186218262 seconds
# iteration 445
# one iteration took 10.325228214263916 seconds
# iteration 446
# one iteration took 11.657890796661377 seconds
# iteration 447
# one iteration took 11.525110006332397 seconds
# iteration 448
# one iteration took 10.227205038070679 seconds
# iteration 449
# one iteration took 10.256945848464966 seconds
# iteration 450
# one iteration took 11.034070014953613 seconds
# iteration 451
# one iteration took 10.962482929229736 seconds
# iteration 452
# one iteration took 10.658846855163574 seconds
# iteration 453
# one iteration took 10.441885948181152 seconds
# iteration 454
# one iteration took 10.347044944763184 seconds
# iteration 455
# one iteration took 10.564398288726807 seconds
# iteration 456
# one iteration took 10.453076124191284 seconds
# iteration 457
# one iteration took 10.444308996200562 seconds
# iteration 458
# one iteration took 10.950904846191406 seconds
# iteration 459
# one iteration took 10.890307188034058 seconds
# iteration 460
# one iteration took 11.68334412574768 seconds
# iteration 461
# one iteration took 10.663510084152222 seconds
# iteration 462
# one iteration took 11.215970277786255 seconds
# iteration 463
# one iteration took 11.166843175888062 seconds
# iteration 464
# one iteration took 10.582579851150513 seconds
# iteration 465
# one iteration took 10.387634992599487 seconds
# iteration 466
# one iteration took 10.5555100440979 seconds
# iteration 467
# one iteration took 11.069002151489258 seconds
# iteration 468
# one iteration took 10.586410284042358 seconds
# iteration 469
# one iteration took 10.26141905784607 seconds
# iteration 470
# one iteration took 10.264631986618042 seconds
# iteration 471
# one iteration took 10.27499794960022 seconds
# iteration 472
# one iteration took 10.249099731445312 seconds
# iteration 473
# one iteration took 10.64357876777649 seconds
# iteration 474
# one iteration took 10.602205038070679 seconds
# iteration 475
# one iteration took 10.165817022323608 seconds
# iteration 476
# one iteration took 10.347843885421753 seconds
# iteration 477
# one iteration took 10.730316877365112 seconds
# iteration 478
# one iteration took 10.415837049484253 seconds
# iteration 479
# one iteration took 10.974185943603516 seconds
# iteration 480
# one iteration took 10.28122591972351 seconds
# iteration 481
# one iteration took 10.214392185211182 seconds
# iteration 482
# one iteration took 12.324774980545044 seconds
# iteration 483
# one iteration took 12.255740880966187 seconds
# iteration 484
# one iteration took 10.782812118530273 seconds
# iteration 485
# one iteration took 10.376751184463501 seconds
# iteration 486
# one iteration took 10.418942928314209 seconds
# iteration 487
# one iteration took 10.828979969024658 seconds
# iteration 488
# one iteration took 10.08542013168335 seconds
# iteration 489
# one iteration took 10.242051124572754 seconds
# iteration 490
# one iteration took 10.167155981063843 seconds
# iteration 491
# one iteration took 10.180038928985596 seconds
# iteration 492
# one iteration took 10.227734088897705 seconds
# iteration 493
# one iteration took 10.190162897109985 seconds
# iteration 494
# one iteration took 10.735267162322998 seconds
# iteration 495
# one iteration took 11.266242265701294 seconds
# iteration 496
# one iteration took 12.575872898101807 seconds
# iteration 497
# one iteration took 12.930148839950562 seconds
# iteration 498
# one iteration took 10.39155912399292 seconds
# iteration 499
# one iteration took 11.000303030014038 seconds

# %%
plt.hist([history_initials_blue[2,:], history_initials_orange[2,:]] ,color=['b', 'r'])
plt.show()

# %%
print(fairs_blue.shape)
# Out:
# (500, 10)

# %%
print(fairs_blue[0])
# Out:
# [35.025 35.231 35.408 35.615 35.635 35.81  35.865 35.941 36.036 36.13 ]

# %%
distribution_over_regressions = np.copy(fairs_blue)
distribution_over_regressions = distribution_over_regressions[:,9]-distribution_over_regressions[:,0]
droppers = distribution_over_regressions < -3.7
distribution_over_regressions = distribution_over_regressions[droppers]

print(sum(distribution_over_regressions < -3.7))
# Out:
# 6

# %%
for i in range(len(droppers)):
    if droppers[i]:
        print (i)
# Out:
# 167
# 203
# 266
# 299
# 444
# 469

# %%
plt.hist(distribution_over_regressions)
plt.xlabel("drop in mean credit score")
plt.ylabel("number of populations")
plt.show()

# %%
big_drop_blues = history_initials_blue[droppers]
big_drop_oranges = history_initials_orange[droppers]

# %%
print(np.average(big_drop_blues, axis=1))
print(np.average(big_drop_oranges, axis=1))
# Out:
# [42.398 38.046 33.084 38.174 36.901 39.324]
# [56.695 58.733 50.307 69.771 65.833 60.173]

# %%
plt.figure(figsize=(7,9), dpi=150)       
sns.set_palette("Paired")


for i in range(6):

    plt.subplot(3, 2, i+1)

    plt.hist([big_drop_blues[i], big_drop_oranges[i]], color=['xkcd:deep sky blue', 'xkcd:dusty orange'])
    
    if(i==0):
        plt.ylabel("number of people")
        plt.legend(("blue population", "orange population"), bbox_to_anchor=(1.8, 1.15), ncol=2)
#         plt.legend(("blue population", "orange population"))
    
    if(i==2):
        plt.ylabel("number of people")
        
    if(i==4):
        plt.ylabel("number of people")
        plt.xlabel("credit score")
        
    if(i==5):
        plt.xlabel("credit score")
        

plt.savefig("plots/worst_offenders.pdf")
plt.show()

# %%
fairs_blue[450:455].shape
# Out:
# (5, 10)

# %%
row_number = how_many_iters_ugh*how_much_history

colours = np.zeros((row_number, 4))
colours[:,3] = 1
colours[:,0:2] = 200/255
colours[:,2] = 255/255
for i in range(row_number):
    colours[i,0:2]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(200/255,200/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(100/255,100/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(0/255,0/255,255/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(np.concatenate((fairs_blue[443:445], fairs_blue[468:471], fairs_blue[52:55], fairs_blue[80:83])), 
           np.concatenate((unfairs_blue[443:445],unfairs_blue[468:471], unfairs_blue[52:55], fairs_blue[80:83])), 
           c=colours)
ax.plot(np.linspace(28,63), np.linspace(28,63), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\mu^{(\cdot)}_{b,u}$ without fairness constraint")
ax.set_xlabel("$\mu^{(\cdot)}_{b,f}$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/GOOD_evolution_blues.pdf")
plt.show()

# %%
num_its = how_many_iters_ugh*how_much_history

colours_orange = np.zeros((num_its, 4))
colours_orange[:,3] = 1
colours_orange[:,0] = 255/255
colours_orange[:,1] = 200/255
colours_orange[:,2] = 0/255
for i in range(num_its):
    colours_orange[i,1]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(255/255,200/255,0/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(255/255,100/255,0/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(255/255,0/255,0/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(fairs_orange[55:62], unfairs_orange[55:62], c=colours_orange)
ax.plot(np.linspace(30,70), np.linspace(30,70), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\mu^{(\cdot)}_{o, u}$ without fairness constraint")
ax.set_xlabel("$\mu^{(\cdot)}_{o, f}$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/GOOD_evolution_oranges.pdf")
plt.show()

# %%
num_its = how_many_iters_ugh*how_much_history

colours_orange = np.zeros((num_its, 4))
colours_orange[:,3] = 1
colours_orange[:,0] = 255/255
colours_orange[:,1] = 200/255
colours_orange[:,2] = 0/255
for i in range(num_its):
    colours_orange[i,1]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(255/255,200/255,0/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(255/255,100/255,0/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(255/255,0/255,0/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(fairs_orange, unfairs_orange, c=colours_orange)
ax.plot(np.linspace(30,80), np.linspace(30,80), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\mu^{(\cdot)}_{o, u}$ without fairness constraint")
ax.set_xlabel("$\mu^{(\cdot)}_{o, f}$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/appendixorange.pdf")
plt.show()

# %%
row_number = how_many_iters_ugh*how_much_history

colours = np.zeros((row_number, 4))
colours[:,3] = 1
colours[:,0:2] = 200/255
colours[:,2] = 255/255
for i in range(row_number):
    colours[i,0:2]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(200/255,200/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(100/255,100/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(0/255,0/255,255/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(fairs_blue, unfairs_blue, c=colours)
ax.plot(np.linspace(27,75), np.linspace(27,75), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\mu^{(\cdot)}_{b,u}$ without fairness constraint")
ax.set_xlabel("$\mu^{(\cdot)}_{b,f}$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/appendixblue.pdf")
plt.show()

# %% [markdown]
# ## Two plots

# %%
row_number = how_many_iters_ugh*how_much_history

colours = np.zeros((row_number, 4))
colours[:,3] = 1
colours[:,0:2] = 200/255
colours[:,2] = 255/255
for i in range(row_number):
    colours[i,0:2]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(200/255,200/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(100/255,100/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(0/255,0/255,255/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(np.concatenate((fairs_blue[443:445], fairs_blue[468:471], fairs_blue[52:55], fairs_blue[80:83])), 
           np.concatenate((unfairs_blue[443:445],unfairs_blue[468:471], unfairs_blue[52:55], fairs_blue[80:83])), 
           c=colours)
ax.plot(np.linspace(28,63), np.linspace(28,63), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\mu_o$ without fairness constraint")
ax.set_xlabel("$\mu_o$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/evolution_blues.pdf")
plt.show()

# %%
std_devs_fair = np.zeros((500,10))
std_devs_unfair = np.zeros((500,10))

for i in range(500):
    for j in range(10):
        std_devs_fair[i,j] = np.std(history_final_blue_fair[i,j,:])
        std_devs_unfair[i,j] = np.std(history_final_blue_unfair[i,j,:])

# %%
std_devs_fair_orange = np.zeros((500,10))
std_devs_unfair_orange = np.zeros((500,10))

for i in range(500):
    for j in range(10):
        std_devs_fair_orange[i,j] = np.std(history_final_orange_fair[i,j,:])
        std_devs_unfair_orange[i,j] = np.std(history_final_orange_unfair[i,j,:])

# %%
row_number = how_many_iters_ugh*how_much_history

colours = np.zeros((row_number, 4))
colours[:,3] = 1
colours[:,0:2] = 200/255
colours[:,2] = 255/255
for i in range(row_number):
    colours[i,0:2]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(200/255,200/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(100/255,100/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(0/255,0/255,255/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(std_devs_fair, std_devs_unfair, c=colours)
ax.plot(np.linspace(21,40), np.linspace(21,40), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\sigma^{(\cdot)}_{b,u}$ without fairness constraint")
ax.set_xlabel("$\sigma^{(\cdot)}_{b,f}$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/evolution_blues_std_dev_all.pdf")
plt.show()

# %%
row_number = how_many_iters_ugh*how_much_history

colours_orange = np.zeros((num_its, 4))
colours_orange[:,3] = 1
colours_orange[:,0] = 255/255
colours_orange[:,1] = 200/255
colours_orange[:,2] = 0/255
for i in range(num_its):
    colours_orange[i,1]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(255/255,200/255,0/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(255/255,100/255,0/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(255/255,0/255,0/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(std_devs_fair_orange[20,35], std_devs_unfair_orange[20,35], c=colours_orange)
ax.plot(np.linspace(20,41), np.linspace(20,41), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\sigma^{(\cdot)}_{o,u}$ without fairness constraint")
ax.set_xlabel("$\sigma^{(\cdot)}_{o,f}$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/evolution_oranges_std_dev_all.pdf")
plt.show()

# %%
plt.hist(history_final_blue_fair[9,0,:])
plt.show()

# %%
plt.hist(history_final_orange_fair[9,0,:])
plt.show()

# %%
row_number = how_many_iters_ugh*how_much_history

colours_orange = np.zeros((num_its, 4))
colours_orange[:,3] = 1
colours_orange[:,0] = 255/255
colours_orange[:,1] = 200/255
colours_orange[:,2] = 0/255
for i in range(num_its):
    colours_orange[i,1]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(255/255,200/255,0/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(255/255,100/255,0/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(255/255,0/255,0/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(std_devs_fair_orange[55:70], std_devs_unfair_orange[55:70], c=colours_orange)
ax.plot(np.linspace(20,41), np.linspace(20,41), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\sigma^{(\cdot)}_{o,u}$ without fairness constraint")
ax.set_xlabel("$\sigma^{(\cdot)}_{o,f}$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/evolution_oranges_std_dev.pdf")
plt.show()

# %%
row_number = how_many_iters_ugh*how_much_history

colours = np.zeros((row_number, 4))
colours[:,3] = 1
colours[:,0:2] = 200/255
colours[:,2] = 255/255
for i in range(row_number):
    colours[i,0:2]-= (i % how_much_history)*200/255/how_much_history

legend_elements = [Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='1st iteration',
                          markerfacecolor=(200/255,200/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='5th iteration',
                          markerfacecolor=(100/255,100/255,255/255), markersize=10),
                   Line2D([0], [0], marker='o', color=(234/255, 234/255, 242/255), label='10th iteration',
                          markerfacecolor=(0/255,0/255,255/255), markersize=10),
                   Line2D([0], [0], label='line y=x', color='black', markersize=3, linewidth=1, alpha=0.5)
                  ]

fig, ax = plt.subplots()
fig.set_dpi(150)
# fig = plt.scatter(fairs_blue, unfairs_blue, c=colours)
ax.scatter(std_devs_fair[55:70], std_devs_unfair[55:70], c=colours)
ax.plot(np.linspace(21,40), np.linspace(21,40), linewidth=1, c='black', alpha=0.5)
ax.set_ylabel("$\sigma^{(\cdot)}_{b,u}$ without fairness constraint")
ax.set_xlabel("$\sigma^{(\cdot)}_{b,f}$ with disparate impact fairness constraint")
ax.legend(handles=legend_elements, loc='best')
plt.savefig("plots/evolution_blues_std_dev.pdf")
plt.show()
